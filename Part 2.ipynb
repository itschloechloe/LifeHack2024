# %%
import numpy as np
import networkx as nx
from deap import base, creator, tools, algorithms
import random
import folium

# Define the coordinates of the hotspots (replace with actual hotspot coordinates)
hotspots = [
    (1.4330621251437414, 103.83778167687922),  # Yishun coordinates
    (1.4371190344748281, 103.83539436698997),
    (1.4252566436379683, 103.83590935114745),
    (1.4248276228794505, 103.84286163671058),
    (1.427916570233905, 103.83204697021661)
]

# Create a graph where nodes are hotspots and edges are Euclidean distances between them
G = nx.complete_graph(len(hotspots))
for i, coord1 in enumerate(hotspots):
    for j, coord2 in enumerate(hotspots):
        if i != j:
            distance = np.linalg.norm(np.array(coord1) - np.array(coord2))
            G[i][j]['weight'] = distance

# Check if the graph is created correctly
print("Graph Nodes:", G.nodes)
print("Graph Edges:", G.edges(data=True))
# Out:
# Graph Nodes: [0, 1, 2, 3, 4]
# Graph Edges: [(0, 1, {'weight': 0.004707203185325589}), (0, 2, {'weight': 0.008026901343781687}), (0, 3, {'weight': 0.009675382133480553}), (0, 4, {'weight': 0.00770477746831806}), (1, 2, {'weight': 0.011873564125773988}), (1, 3, {'weight': 0.014381895427490602}), (1, 4, {'weight': 0.00979236504955768}), (2, 3, {'weight': 0.006965510272948608}), (2, 4, {'weight': 0.004689690389640978}), (3, 4, {'weight': 0.011247159958603328})]

# %%
# Create a Folium map centered around the first hotspot
map_center = hotspots[0]
mymap = folium.Map(location=map_center, zoom_start=13)

# Add crime hotspots to the map as markers
for i, coord in enumerate(hotspots):
    folium.Marker(location=coord, popup=f"Hotspot {i+1}").add_to(mymap)

# Add edges of the graph as lines to the map
for edge in G.edges(data=True):
    node1, node2, data = edge
    coord1, coord2 = hotspots[node1], hotspots[node2]
    folium.PolyLine(locations=[coord1, coord2], color='blue', weight=2.5, opacity=1).add_to(mymap)

# Save or display the map
mymap.save('graph_map.html')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_507c3c775a1120b45cb7b8036ad481f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_507c3c775a1120b45cb7b8036ad481f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_507c3c775a1120b45cb7b8036ad481f5 = L.map(
#                 &quot;map_507c3c775a1120b45cb7b8036ad481f5&quot;,
#                 {
#                     center: [1.4330621251437414, 103.83778167687922],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e230ba8c3faf7c2056d7f3211778cbe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5e230ba8c3faf7c2056d7f3211778cbe.addTo(map_507c3c775a1120b45cb7b8036ad481f5);
#
#
#             var marker_1bfe1c95d4ae95855a7c1fde76ca0e2c = L.marker(
#                 [1.4330621251437414, 103.83778167687922],
#                 {}
#             ).addTo(map_507c3c775a1120b45cb7b8036ad481f5);
#
#
#         var popup_11c352122ae5b4cda62b121b05b148e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_650efa8bc8e9a975a3ee08570ffe3640 = $(`&lt;div id=&quot;html_650efa8bc8e9a975a3ee08570ffe3640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 1&lt;/div&gt;`)[0];
#                 popup_11c352122ae5b4cda62b121b05b148e5.setContent(html_650efa8bc8e9a975a3ee08570ffe3640);
#
#
#
#         marker_1bfe1c95d4ae95855a7c1fde76ca0e2c.bindPopup(popup_11c352122ae5b4cda62b121b05b148e5)
#         ;
#
#
#
#
#             var marker_043a6a8eeaec3796e6c7887a12acc7b5 = L.marker(
#                 [1.4371190344748281, 103.83539436698997],
#                 {}
#             ).addTo(map_507c3c775a1120b45cb7b8036ad481f5);
#
#
#         var popup_c84bdb168335225973f1cdc8f1d9565f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a21dfacc613dd6f1626d2386a77a86b = $(`&lt;div id=&quot;html_5a21dfacc613dd6f1626d2386a77a86b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 2&lt;/div&gt;`)[0];
#                 popup_c84bdb168335225973f1cdc8f1d9565f.setContent(html_5a21dfacc613dd6f1626d2386a77a86b);
#
#
#
#         marker_043a6a8eeaec3796e6c7887a12acc7b5.bindPopup(popup_c84bdb168335225973f1cdc8f1d9565f)
#         ;
#
#
#
#
#             var marker_52d7a9172e71bd4dc60597cf70756faa = L.marker(
#                 [1.4252566436379683, 103.83590935114745],
#                 {}
#             ).addTo(map_507c3c775a1120b45cb7b8036ad481f5);
#
#
#         var popup_bd4337a7ccc3cb07578ac4ff0fb3f149 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c62b3ddcdd6290d5d66d9908ca6fa342 = $(`&lt;div id=&quot;html_c62b3ddcdd6290d5d66d9908ca6fa342&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 3&lt;/div&gt;`)[0];
#                 popup_bd4337a7ccc3cb07578ac4ff0fb3f149.setContent(html_c62b3ddcdd6290d5d66d9908ca6fa342);
#
#
#
#         marker_52d7a9172e71bd4dc60597cf70756faa.bindPopup(popup_bd4337a7ccc3cb07578ac4ff0fb3f149)
#         ;
#
#
#
#
#             var marker_8a3c2cc001117ef342767303b96689cf = L.marker(
#                 [1.4248276228794505, 103.84286163671058],
#                 {}
#             ).addTo(map_507c3c775a1120b45cb7b8036ad481f5);
#
#
#         var popup_113cb50443aa7f6a94fe26344df55d16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be1ba2fa7ab5d6c9d2053a92f32cf542 = $(`&lt;div id=&quot;html_be1ba2fa7ab5d6c9d2053a92f32cf542&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 4&lt;/div&gt;`)[0];
#                 popup_113cb50443aa7f6a94fe26344df55d16.setContent(html_be1ba2fa7ab5d6c9d2053a92f32cf542);
#
#
#
#         marker_8a3c2cc001117ef342767303b96689cf.bindPopup(popup_113cb50443aa7f6a94fe26344df55d16)
#         ;
#
#
#
#
#             var marker_8d410b9e2060e70939b51c23eb044eea = L.marker(
#                 [1.427916570233905, 103.83204697021661],
#                 {}
#             ).addTo(map_507c3c775a1120b45cb7b8036ad481f5);
#
#
#         var popup_77bf549cfff8dd38b7e0d8cee88cb635 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b9841fc8bcb903585633ddc76ce97a7 = $(`&lt;div id=&quot;html_8b9841fc8bcb903585633ddc76ce97a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 5&lt;/div&gt;`)[0];
#                 popup_77bf549cfff8dd38b7e0d8cee88cb635.setContent(html_8b9841fc8bcb903585633ddc76ce97a7);
#
#
#
#         marker_8d410b9e2060e70939b51c23eb044eea.bindPopup(popup_77bf549cfff8dd38b7e0d8cee88cb635)
#         ;
#
#
#
#
#             var poly_line_f3b1f1dc44ba6d91eb01dd99135e18ed = L.polyline(
#                 [[1.433062125143

# %%
import itertools

# Define the fitness function
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("PatrolPolice", list, fitness=creator.FitnessMin)

# Define the evaluation function
def eval_route(patrol_police):
    distance = 0
    for i in range(len(patrol_police) - 1):
        distance += G[patrol_police[i]][patrol_police[i + 1]]['weight']
    distance += G[patrol_police[-1]][patrol_police[0]]['weight']
    return distance,

# Genetic Algorithm setup
toolbox = base.Toolbox()
toolbox.register("indices", itertools.permutations, range(len(hotspots)))
toolbox.register("patrol_police", lambda: list(toolbox.indices()))
toolbox.register("mate", tools.cxPartialyMatched)
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_route)

# Create an initial population
population = [creator.PatrolPolice(p) for p in toolbox.patrol_police()]

# Evaluate the fitness of initial population
fitnesses = list(map(toolbox.evaluate, population))
for ind, fit in zip(population, fitnesses):
    ind.fitness.values = fit
    print("Initial individual:", ind)  # Debug print
    print("Fitness:", fit)  # Debug print

print("Number of hotspots:", len(hotspots))  # Debug print
print("Number of nodes in the graph:", len(G.nodes))  # Debug print
# Out:
# Initial individual: [0, 1, 2, 3, 4]
# Fitness: (0.04249821501096957,)
# Initial individual: [0, 1, 2, 4, 3]
# Fitness: (0.04219299979282444,)
# Initial individual: [0, 1, 3, 2, 4]
# Fitness: (0.03844907674372384,)
# Initial individual: [0, 1, 3, 4, 2]
# Fitness: (0.04305285030484218,)
# Initial individual: [0, 1, 4, 2, 3]
# Fitness: (0.03583015103095341,)
# Initial individual: [0, 1, 4, 3, 2]
# Fitness: (0.040739139810216894,)
# Initial individual: [0, 2, 1, 3, 4]
# Fitness: (0.053234298323967665,)
# Initial individual: [0, 2, 1, 4, 3]
# Fitness: (0.05061537261119724,)
# Initial individual: [0, 2, 3, 1, 4]
# Fitness: (0.046871449562096636,)
# Initial individual: [0, 2, 3, 4, 1]
# Fitness: (0.040739139810216894,)
# Initial individual: [0, 2, 4, 1, 3]
# Fitness: (0.046566234343951504,)
# Initial individual: [0, 2, 4, 3, 1]
# Fitness: (0.04305285030484218,)
# Initial individual: [0, 3, 1, 2, 4]
# Fitness: (0.048325309544704174,)
# Initial individual: [0, 3, 1, 4, 2]
# Fitness: (0.0465662343439515,)
# Initial individual: [0, 3, 2, 1, 4]
# Fitness: (0.046011599050078886,)
# Initial individual: [0, 3, 2, 4, 1]
# Fitness: (0.035830151030953404,)
# Initial individual: [0, 3, 4, 1, 2]
# Fitness: (0.05061537261119724,)
# Initial individual: [0, 3, 4, 2, 1]
# Fitness: (0.04219299979282443,)
# Initial individual: [0, 4, 1, 2, 3]
# Fitness: (0.046011599050078886,)
# Initial individual: [0, 4, 1, 3, 2]
# Fitness: (0.046871449562096636,)
# Initial individual: [0, 4, 2, 1, 3]
# Fitness: (0.04832530954470418,)
# Initial individual: [0, 4, 2, 3, 1]
# Fitness: (0.03844907674372384,)
# Initial individual: [0, 4, 3, 1, 2]
# Fitness: (0.05323429832396767,)
# Initial individual: [0, 4, 3, 2, 1]
# Fitness: (0.04249821501096957,)
# Initial individual: [1, 0, 2, 3, 4]
# Fitness: (0.040739139810216894,)
# Initial individual: [1, 0, 2, 4, 3]
# Fitness: (0.04305285030484218,)
# Initial individual: [1, 0, 3, 2, 4]
# Fitness: (0.035830151030953404,)
# Initial individual: [1, 0, 3, 4, 2]
# Fitness: (0.04219299979282444,)
# Initial individual: [1, 0, 4, 2, 3]
# Fitness: (0.03844907674372384,)
# Initial individual: [1, 0, 4, 3, 2]
# Fitness: (0.04249821501096958,)
# Initial individual: [1, 2, 0, 3, 4]
# Fitness: (0.05061537261119724,)
# Initial individual: [1, 2, 0, 4, 3]
# Fitness: (0.05323429832396767,)
# Initial individual: [1, 2, 3, 0, 4]
# Fitness: (0.046011599050078886,)
# Initial individual: [1, 2, 3, 4, 0]
# Fitness: (0.04249821501096957,)
# Initial individual: [1, 2, 4, 0, 3]
# Fitness: (0.04832530954470418,)
# Initial individual: [1, 2, 4, 3, 0]
# Fitness: (0.04219299979282443,)
# Initial individual: [1, 3, 0, 2, 4]
# Fitness: (0.0465662343439515,)
# Initial individual: [1, 3, 0, 4, 2]
# Fitness: (0.04832530954470418,)
# Initial individual: [1, 3, 2, 0, 4]
# Fitness: (0.046871449562096636,)
# Initial individual: [1, 3, 2, 4, 0]
# Fitness: (0.03844907674372384,)
# Initial individual: [1, 3, 4, 0, 2]
# Fitness: (0.05323429832396767,)
# Initial individual: [1, 3, 4, 2, 0]
# Fitness: (0.04305285030484219,)
# Initial individual: [1, 4, 0, 2, 3]
# Fitness: (0.046871449562096636,)
# Initial individual: [1, 4, 0, 3, 2]
# Fitness: (0.046011599050078886,)
# Initial individual: [1, 4, 2, 0, 3]
# Fitness: (0.046566234343951504,)
# Initial individual: [1, 4, 2, 3, 0]
# Fitness: (0.03583015103095341,)
# Initial individual: [1, 4, 3, 0, 2]
# Fitness: (0.05061537261119724,)
# Initial individual: [1, 4, 3, 2, 0]
# Fitness: (0.040739139810216894,)
# Initial individual: [2, 0, 1, 3, 4]
# Fitness: (0.04305285030484218,)
# Initial individual: [2, 0, 1, 4, 3]
# Fitness: (0.040739139810216894,)
# Initial individual: [2, 0, 3, 1, 4]
# Fitness: (0.0465662343439515,)
# Initial individual: [2, 0, 3, 4, 1]
# Fitness: (0.05061537261119724,)
# Initial individual: [2, 0, 4, 1, 3]
# Fitness: (0.04687144956209664,)
# Initial individual: [2, 0, 4, 3, 1]
# Fitness: (0.05323429832396767,)
# Initial individual: [2, 1, 0, 3, 4]
# Fitness: (0.04219299979282443,)
# Initial individual: [2, 1, 0, 4, 3]
# Fitness: (0.04249821501096957,)
# Initial individual: [2, 1, 3, 0, 4]
# Fitness: (0.048325309544704174,)
# Initial individual: [2, 1, 3, 4, 0]
# Fitness: (0.053234298323967665,)
# Initial individual: [2, 1, 4, 0, 3]
# Fitness: (0.04601159905007889,)
# Initial individual: [2, 1, 4, 3, 0]
# Fitness: (0.05061537261119724,)
# Initial individual: [2, 3, 0, 1, 4]
# Fitness: (0.035830151030953404,)
# Initial individual: [2, 3, 0, 4, 1]
# Fitness: (0.046011599050078886,)
# Initial individual: [2, 3, 1, 0, 4]
# Fitness: (0.03844907674372383,)
# Initial individual: [2, 3, 1, 4, 0]
# Fitness: (0.046871449562096636,)
# Initial individual: [2, 3, 4, 0, 1]
# Fitness: (0.04249821501096958,)
# Initial individual: [2, 3, 4, 1, 0]
# Fitness: (0.040739139810216894,)
# Initial individual: [2, 4, 0, 1, 3]
# Fitness: (0.03844907674372384,)
# Initial individual: [2, 4, 0, 3, 1]
# Fitness: (0.04832530954470418,)
# Initial individual: [2, 4, 1, 0, 3]
# Fitness: (0.035830151030953404,)
# Initial individual: [2, 4, 1, 3, 0]
# Fitness: (0.046566234343951504,)
# Initial individual: [2, 4, 3, 0, 1]
# Fitness: (0.04219299979282444,)
# Initial individual: [2, 4, 3, 1, 0]
# Fitness: (0.04305285030484218,)
# Initial individual: [3, 0, 1, 2, 4]
# Fitness: (0.04219299979282444,)
# Initial individual: [3, 0, 1, 4, 2]
# Fitness: (0.035830151030953404,)
# Initial individual: [3, 0, 2, 1, 4]
# Fitness: (0.05061537261119724,)
# Initial individual: [3, 0, 2, 4, 1]
# Fitness: (0.046566234343951504,)
# Initial individual: [3, 0, 4, 1, 2]
# Fitness: (0.04601159905007889,)
# Initial individual: [3, 0, 4, 2, 1]
# Fitness: (0.04832530954470418,)
# Initial individual: [3, 1, 0, 2, 4]
# Fitness: (0.04305285030484218,)
# Initial individual: [3, 1, 0, 4, 2]
# Fitness: (0.03844907674372384,)
# Initial individual: [3, 1, 2, 0, 4]
# Fitness: (0.053234298323967665,)
# Initial individual: [3, 1, 2, 4, 0]
# Fitness: (0.04832530954470418,)
# Initial individual: [3, 1, 4, 0, 2]
# Fitness: (0.046871449562096636,)
# Initial individual: [3, 1, 4, 2, 0]
# Fitness: (0.046566234343951504,)
# Initial individual: [3, 2, 0, 1, 4]
# Fitness: (0.040739139810216894,)
# Initial individual: [3, 2, 0, 4, 1]
# Fitness: (0.046871449562096636,)
# Initial individual: [3, 2, 1, 0, 4]
# Fitness: (0.04249821501096957,)
# Initial individual: [3, 2, 1, 4, 0]
# Fitness: (0.046011599050078886,)
# Initial individual: [3, 2, 4, 0, 1]
# Fitness: (0.03844907674372384,)
# Initial individual: [3, 2, 4, 1, 0]
# Fitness: (0.03583015103095341,)
# Initial individual: [3, 4, 0, 1, 2]
# Fitness: (0.04249821501096957,)
# Initial individual: [3, 4, 0, 2, 1]
# Fitness: (0.05323429832396767,)
# Initial individual: [3, 4, 1, 0, 2]
# Fitness: (0.040739139810216894,)
# Initial individual: [3, 4, 1, 2, 0]
# Fitness: (0.05061537261119724,)
# Initial individual: [3, 4, 2, 0, 1]
# Fitness: (0.04305285030484218,)
# Initial individual: [3, 4, 2, 1, 0]
# Fitness: (0.04219299979282444,)
# Initial individual: [4, 0, 1, 2, 3]
# Fitness: (0.04249821501096957,)
# Initial individual: [4, 0, 1, 3, 2]
# Fitness: (0.03844907674372384,)
# Initial individual: [4, 0, 2, 1, 3]
# Fitness: (0.053234298323967665,)
# Initial individual: [4, 0, 2, 3, 1]
# Fitness: (0.04687144956209664,)
# Initial individual: [4, 0, 3, 1, 2]
# Fitness: (0.048325309544704174,)
# Initial individual: [4, 0, 3, 2, 1]
# Fitness: (0.04601159905007889,)
# Initial individual: [4, 1, 0, 2, 3]
# Fitness: (0.040739139810216894,)
# Initial individual: [4, 1, 0, 3, 2]
# Fitness: (0.035830151030953404,)
# Initial individual: [4, 1, 2, 0, 3]
# Fitness: (0.05061537261119724,)
# Initial individual: [4, 1, 2, 3, 0]
# Fitness: (0.046011599050078886,)
# Initial individual: [4, 1, 3, 0, 2]
# Fitness: (0.0465662343439515,)
# Initial individual: [4, 1, 3, 2, 0]
# Fitness: (0.046871449562096636,)
# Initial individual: [4, 2, 0, 1, 3]
# Fitness: (0.04305285030484218,)
# Initial individual: [4, 2, 0, 3, 1]
# Fitness: (0.046566234343951504,)
# Initial individual: [4, 2, 1, 0, 3]
# Fitness: (0.04219299979282444,)
# Initial individual: [4, 2, 1, 3, 0]
# Fitness: (0.04832530954470418,)
# Initial individual: [4, 2, 3, 0, 1]
# Fitness: (0.035830151030953404,)
# Initial individual: [4, 2, 3, 1, 0]
# Fitness: (0.03844907674372384,)
# Initial individual: [4, 3, 0, 1, 2]
# Fitness: (0.04219299979282443,)
# Initial individual: [4, 3, 0, 2, 1]
# Fitness: (0.05061537261119724,)
# Initial individual: [4, 3, 1, 0, 2]
# Fitness: (0.04305285030484218,)
# Initial individual: [4, 3, 1, 2, 0]
# Fitness: (0.05323429832396767,)
# Initial individual: [4, 3, 2, 0, 1]
# Fitness: (0.040739139810216894,)
# Initial individual: [4, 3, 2, 1, 0]
# Fitness: (0.04249821501096958,)
# Number of hotspots: 5
# Number of nodes in the graph: 5

# %%
algorithms.eaSimple(population, toolbox, cxpb=0.7, mutpb=0.2, ngen=50, verbose=False)

# Get the best route
best_patrol_police = tools.selBest(population, k=1)[0]  
best_route = [hotspots[i] for i in best_patrol_police]

# %%
# Visualize the optimal route with annotations
map_center = [np.mean([coord[0] for coord in hotspots]), np.mean([coord[1] for coord in hotspots])]
mymap = folium.Map(location=map_center, zoom_start=13)

# Add crime hotspots to the map
for i, coord in enumerate(hotspots):
    folium.CircleMarker(location=coord, radius=5, color='red').add_to(mymap)
    folium.Marker(location=coord, icon=folium.Icon(color='green'), popup=f"Hotspot {i+1}").add_to(mymap)  # Add hotspot numbers

# Add the optimal patrol route to the map with annotations
for i in range(len(best_route)):
    coord = best_route[i]
    folium.Marker(location=coord, icon=folium.DivIcon(html=f"<div style='font-size: large;'>{i+1}</div>")).add_to(mymap)  # Add visit numbers
    if i < len(best_route) - 1:
        next_coord = best_route[i+1]
        folium.PolyLine(locations=[coord, next_coord], color='blue', weight=2.5, opacity=1).add_to(mymap)

# Connect the last hotspot to the starting point
folium.PolyLine(locations=[best_route[-1], best_route[0]], color='blue', weight=2.5, opacity=1).add_to(mymap)

# Save or display the map
mymap.save('optimal_patrol_route_with_annotations.html')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b939f0a404de41d0645ecc4c720f4ea4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b939f0a404de41d0645ecc4c720f4ea4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b939f0a404de41d0645ecc4c720f4ea4 = L.map(
#                 &quot;map_b939f0a404de41d0645ecc4c720f4ea4&quot;,
#                 {
#                     center: [1.429636399273979, 103.83679880038878],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fd9f450e6962482971177046f6b0f9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3fd9f450e6962482971177046f6b0f9c.addTo(map_b939f0a404de41d0645ecc4c720f4ea4);
#
#
#             var circle_marker_6a91d5ba05fb63181ca62b1b52f2b6f1 = L.circleMarker(
#                 [1.4330621251437414, 103.83778167687922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b939f0a404de41d0645ecc4c720f4ea4);
#
#
#             var marker_fd8481dd2424eee4a461a516ccf2321f = L.marker(
#                 [1.4330621251437414, 103.83778167687922],
#                 {}
#             ).addTo(map_b939f0a404de41d0645ecc4c720f4ea4);
#
#
#             var icon_bb5a31138251ef7e603382a119fa0a1b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd8481dd2424eee4a461a516ccf2321f.setIcon(icon_bb5a31138251ef7e603382a119fa0a1b);
#
#
#         var popup_78151a7d7e6813d9095cbf60b49fc675 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6747b0ca7596b1e79553fcf550153629 = $(`&lt;div id=&quot;html_6747b0ca7596b1e79553fcf550153629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 1&lt;/div&gt;`)[0];
#                 popup_78151a7d7e6813d9095cbf60b49fc675.setContent(html_6747b0ca7596b1e79553fcf550153629);
#
#
#
#         marker_fd8481dd2424eee4a461a516ccf2321f.bindPopup(popup_78151a7d7e6813d9095cbf60b49fc675)
#         ;
#
#
#
#
#             var circle_marker_15658c203ff0e2a0b945744e4d464025 = L.circleMarker(
#                 [1.4371190344748281, 103.83539436698997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b939f0a404de41d0645ecc4c720f4ea4);
#
#
#             var marker_19d100bdbe1cccfea8ce529cb6b2b3c4 = L.marker(
#                 [1.4371190344748281, 103.83539436698997],
#                 {}
#             ).addTo(map_b939f0a404de41d0645ecc4c720f4ea4);
#
#
#             var icon_c356bcaf43f79f3ec55441763e5263b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_19d100bdbe1cccfea8ce529cb6b2b3c4.setIcon(icon_c356bcaf43f79f3ec55441763e5263b0);
#
#
#         var popup_3ed3af2d1603b8ba92856d4ab094c0cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96957e72d9608ca6eab9d3db4d186c38 = $(`&lt;div id=&quot;html_96957e72d9608ca6eab9d3db4d186c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hotspot 2&lt;/div&gt;`)[0];
#                 popup_3ed3af2d1603b8ba92856d4ab094c0cb.setContent(html_96957e72d9608ca6eab9d3db4d186c38);
#
#
#
#         marker_19d100bdbe1cccfea8ce529cb6b2b3c4.bindPopup(popup_3ed3af2d1603b8ba92856d4ab094c0cb)
#         ;
#
#
#
#
#             var circle_marker_dadc1b39b085f2885ef641a01caa1efa = L.circleMarker(
#                 [1.4252566436379683, 103.83590935114745],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashO
